# %% [markdown]
# # Data Preprocessing - EIT - Machine Learning
#
# ### Copyright (c) 2018, Faststream Technologies
# ### Author: Sudhanva Narayana

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('../assets/EIT Clean.xlsx', skip_rows=[0, 1, 2])

# %%
df.head()
# Out:
#                                                                        1  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                 0.05
# Shreejith 23  kilo   Male forearm 1        72     8                  117
# Vinod     65  kilo   Male forearm 1        79     8                  1.8
# Sudhanva  23  kilo   Male forearm 1        90     8                 0.05
#
#                                                                 Unnamed: 1  \
# name      age metric sex  part    distance weight no_electrodes    res_max
# Shreyas   23  kilo   Male forearm 1        85     8                  0.058
# Shreejith 23  kilo   Male forearm 1        72     8                    122
# Vinod     65  kilo   Male forearm 1        79     8                    2.8
# Sudhanva  23  kilo   Male forearm 1        90     8                   0.05
#
#                                                                        2  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   17
# Shreejith 23  kilo   Male forearm 1        72     8                  116
# Vinod     65  kilo   Male forearm 1        79     8                  9.6
# Sudhanva  23  kilo   Male forearm 1        90     8                  4.5
#
#                                                                 Unnamed: 3  \
# name      age metric sex  part    distance weight no_electrodes    res_max
# Shreyas   23  kilo   Male forearm 1        85     8                     18
# Shreejith 23  kilo   Male forearm 1        72     8                    138
# Vinod     65  kilo   Male forearm 1        79     8                    9.6
# Sudhanva  23  kilo   Male forearm 1        90     8                    4.5
#
#                                                                        3  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                    8
# Shreejith 23  kilo   Male forearm 1        72     8                   95
# Vinod     65  kilo   Male forearm 1        79     8                  7.5
# Sudhanva  23  kilo   Male forearm 1        90     8                10.52
#
#                                                                 Unnamed: 5  \
# name      age metric sex  part    distance weight no_electrodes    res_max
# Shreyas   23  kilo   Male forearm 1        85     8                      9
# Shreejith 23  kilo   Male forearm 1        72     8                    103
# Vinod     65  kilo   Male forearm 1        79     8                    7.8
# Sudhanva  23  kilo   Male forearm 1        90     8                  10.52
#
#                                                                        4  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   70
# Shreejith 23  kilo   Male forearm 1        72     8                   97
# Vinod     65  kilo   Male forearm 1        79     8                  6.5
# Sudhanva  23  kilo   Male forearm 1        90     8                 5.32
#
#                                                                 Unnamed: 7  \
# name      age metric sex  part    distance weight no_electrodes    res_max
# Shreyas   23  kilo   Male forearm 1        85     8                     72
# Shreejith 23  kilo   Male forearm 1        72     8                    100
# Vinod     65  kilo   Male forearm 1        79     8                    6.5
# Sudhanva  23  kilo   Male forearm 1        90     8                    5.9
#
#                                                                        5  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   87
# Shreejith 23  kilo   Male forearm 1        72     8                  102
# Vinod     65  kilo   Male forearm 1        79     8                  3.7
# Sudhanva  23  kilo   Male forearm 1        90     8                    7
#
#                                                                 Unnamed: 9  \
# name      age metric sex  part    distance weight no_electrodes    res_max
# Shreyas   23  kilo   Male forearm 1        85     8                     88
# Shreejith 23  kilo   Male forearm 1        72     8                    104
# Vinod     65  kilo   Male forearm 1        79     8                    3.7
# Sudhanva  23  kilo   Male forearm 1        90     8                      8
#
#                                                                   ...     \
# name      age metric sex  part    distance weight no_electrodes   ...
# Shreyas   23  kilo   Male forearm 1        85     8               ...
# Shreejith 23  kilo   Male forearm 1        72     8               ...
# Vinod     65  kilo   Male forearm 1        79     8               ...
# Sudhanva  23  kilo   Male forearm 1        90     8               ...
#
#                                                                      4.2  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   65
# Shreejith 23  kilo   Male forearm 1        72     8                    8
# Vinod     65  kilo   Male forearm 1        79     8                  1.9
# Sudhanva  23  kilo   Male forearm 1        90     8                  4.3
#
#                                                                      5.1  \
# name      age metric sex  part    distance weight no_electrodes  res_max
# Shreyas   23  kilo   Male forearm 1        85     8                   72
# Shreejith 23  kilo   Male forearm 1        72     8                    9
# Vinod     65  kilo   Male forearm 1        79     8                    2
# Sudhanva  23  kilo   Male forearm 1        90     8                  4.3
#
#                                                                      5.2  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                  109
# Shreejith 23  kilo   Male forearm 1        72     8                  4.5
# Vinod     65  kilo   Male forearm 1        79     8                  1.6
# Sudhanva  23  kilo   Male forearm 1        90     8                  1.9
#
#                                                                      6.1  \
# name      age metric sex  part    distance weight no_electrodes  res_max
# Shreyas   23  kilo   Male forearm 1        85     8                  110
# Shreejith 23  kilo   Male forearm 1        72     8                  4.5
# Vinod     65  kilo   Male forearm 1        79     8                  1.6
# Sudhanva  23  kilo   Male forearm 1        90     8                  1.9
#
#                                                                      6.2  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   77
# Shreejith 23  kilo   Male forearm 1        72     8                  3.5
# Vinod     65  kilo   Male forearm 1        79     8                  9.5
# Sudhanva  23  kilo   Male forearm 1        90     8                  0.5
#
#                                                                      7.1  \
# name      age metric sex  part    distance weight no_electrodes  res_max
# Shreyas   23  kilo   Male forearm 1        85     8                   82
# Shreejith 23  kilo   Male forearm 1        72     8                  3.5
# Vinod     65  kilo   Male forearm 1        79     8                  9.5
# Sudhanva  23  kilo   Male forearm 1        90     8                  0.5
#
#                                                                      7.2  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   42
# Shreejith 23  kilo   Male forearm 1        72     8                  0.8
# Vinod     65  kilo   Male forearm 1        79     8                  5.3
# Sudhanva  23  kilo   Male forearm 1        90     8                 0.65
#
#                                                                      8.1  \
# name      age metric sex  part    distance weight no_electrodes  res_max
# Shreyas   23  kilo   Male forearm 1        85     8                   43
# Shreejith 23  kilo   Male forearm 1        72     8                  0.8
# Vinod     65  kilo   Male forearm 1        79     8                  5.3
# Sudhanva  23  kilo   Male forearm 1        90     8                 0.65
#
#                                                                      8.2  \
# name      age metric sex  part    distance weight no_electrodes  res_min
# Shreyas   23  kilo   Male forearm 1        85     8                   21
# Shreejith 23  kilo   Male forearm 1        72     8                   93
# Vinod     65  kilo   Male forearm 1        79     8                  3.3
# Sudhanva  23  kilo   Male forearm 1        90     8                  6.5
#
#                                                                      1.2
# name      age metric sex  part    distance weight no_electrodes  res_max
# Shreyas   23  kilo   Male forearm 1        85     8                   23
# Shreejith 23  kilo   Male forearm 1        72     8                   96
# Vinod     65  kilo   Male forearm 1        79     8                  3.3
# Sudhanva  23  kilo   Male forearm 1        90     8                  6.8
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index([            1,  'Unnamed: 1',             2,  'Unnamed: 3',
#                    3,  'Unnamed: 5',             4,  'Unnamed: 7',
#                    5,  'Unnamed: 9',             6, 'Unnamed: 11',
#                    7, 'Unnamed: 13',             8, 'Unnamed: 15',
#                '1.1',         '2.1',         '2.2',         '3.1',
#                '3.2',         '4.1',         '4.2',         '5.1',
#                '5.2',         '6.1',         '6.2',         '7.1',
#                '7.2',         '8.1',         '8.2',         '1.2'],
#       dtype='object')
